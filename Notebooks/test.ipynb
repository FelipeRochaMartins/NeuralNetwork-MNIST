# %%
# %run startup.py

# %%
from Core.neural_network import NeuralNetwork
from Utils.network_visualizer import generate_network_graph

# Create a small network for visualization
network = NeuralNetwork(input_size=4, hidden_layers=[10,10,10,10], output_size=2)
generate_network_graph(network)

# %%
from Core.neural_network import NeuralNetwork
from Utils.network_visualizer import generate_network_graph

network = NeuralNetwork(input_size=3, hidden_layers=[4], output_size=2)

generate_network_graph(network)
# Out:
# Neural Network Test Results:
# ------------------------------
#
# 1. Shape Tests:
# Input shape: (1, 3)
# Hidden layer shape: (1, 4)
# Output shape: (1, 2)
#
# 2. Activation Values:
# Hidden layer (after ReLU):
# [[0.02845703 0.02701342 0.0178219  0.00024511]]
# Output layer (after Softmax):
# [[0.49990058 0.50009942]]
#
# 3. Softmax Properties:
# Sum of probabilities: 1.0
# All values between 0 and 1: True
